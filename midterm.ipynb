# %% [markdown]
# # Midterm Project - Team Cartwheel A
#
# **Girish Krishnan, Ishaan H. Kavoori, and Gokul Swaminathan**
#
# ### Generating a Disk
#
# First, we generate the disk of points surrounding the target galaxy nucleus.

# %%
# Usage: ./disk_point_distribution NUM_RINGS NUM_PARTICLES_PER_RING VALUE_OF_G SCALE_LENGTH DISK_RADIUS HOST_MASS <data file name>
# !g++ -o disk_point_distribution disk_point_distribution.cpp
# !./disk_point_distribution 16 16 1.0 10.0 40.0 1.0 disk_settings.dat
# Out:
# Radii = 6.81 8.64 8.84 11.85 11.93 12.47 12.55 13.46 13.54 14.01 14.82 15.84 16.19 17.83 22.1 27.39

# %%
# Usage: ./disk <setup_file> <output_file>
# !g++ -o disk_initial_conditions disk_initial_conditions.cpp
# !./disk_initial_conditions disk_settings.dat disk_initial_conditions.dat
# Out:
# Generating disk galaxy model...
# numRings = 16
# numParticlesPerRing = 16
# G = 1.000000
# scaleLength = 10.000000
# ringRadii = 6.810000 8.640000 8.840000 11.850000 11.930000 12.470000 12.550000 13.460000 13.540000 14.010000 14.820000 15.840000 16.190000 17.830000 22.100000 27.390000
# hostMass = 1.000000

# %% [markdown]
# ### Plotting the disk generated

# %%
# Usage: python plotting_initial_disk.py <disk_data_filename> <output_image_filename>
# !python plotting_initial_disk.py disk_initial_conditions.dat initial_disk.png
# Display the image
from IPython.display import Image
Image(filename='initial_disk.png')

# %% [markdown]
# ### Running the simulation

# %%
# Usage: ./simulation <simulation settings file> <disk initial conditions file> <data log file>
# !g++ -o simulation simulation.cpp
# !./simulation simulation_settings.dat disk_initial_conditions.dat data_log.dat
# Out:
# Host nucleus:
# m = 1.000000
# x = 0.000000 y = 0.000000 z = 0.000000
# vx = 0.000000 vy = 0.000000 vz = 0.000000
# Intruder nucleus:
# m = 0.667000
# x = 0.000000 y = 0.000000 z = 10.000000
# vx = 0.000000 vy = 0.000000 vz = -0.447000
# Integration parameters:
# nout = 2 dt = 0.100000 mstep = 800 soft = 1.000000
# Number of points in disk: 256
# Number of points read: 256
# First 5 points:
# x = 6.810000 y = 0.000000 z = 0.000000 vx = -0.000000 vy = 0.383201 vz = 0.000000
# x = 6.291620 y = 2.606074 z = 0.000000 vx = -0.146645 vy = 0.354031 vz = 0.000000
# x = 4.815397 y = 4.815397 z = 0.000000 vx = -0.270964 vy = 0.270964 vz = 0.000000
# x = 2.606074 y = 6.291620 z = 0.000000 vx = -0.354031 vy = 0.146645 vz = 0.000000
# x = 0.000000 y = 6.810000 z = 0.000000 vx = -0.383201 vy = 0.000000 vz = 0.000000

# %% [markdown]
# ### Visualizing the simulation

# %%
# Usage: python animate.py <data_log_filename> <output video filename>
# !python animate.py data_log.dat animation.mp4

# Use IFrame to display the animation in the notebook
from IPython.display import IFrame
IFrame('animation.mp4', width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="animation.mp4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
