# %% [markdown]
# # Midterm Project - Team Cartwheel A
#
# ### Generating a Disk

# %%
# !gcc -o disk disk.cpp
# !./disk disk_settings.dat disk_initial_conditions.dat
# Out:
# Generating disk galaxy model...
# numRings = 16
# numParticlesPerRing = 16
# G = 1.000000
# scaleLength = 10.000000
# ringRadii = 1.000000 2.000000 3.000000 4.000000 5.000000 6.000000 7.000000 8.500000 10.000000 11.500000 13.000000 15.000000 17.000000 19.000000 22.000000 25.000000
# ringWidths = 0.100000 0.100000 0.100000 0.100000 0.100000 0.100000 0.100000 0.200000 0.200000 0.200000 0.200000 0.300000 0.300000 0.300000 0.400000 0.400000

# %% [markdown]
# ### Plotting the disk generated

# %%
# !python plotting_initial_disk.py disk_initial_conditions.dat initial_disk.png
# Display the image
from IPython.display import Image
Image(filename='initial_disk.png')

# %% [markdown]
# ### Running the simulation

# %%
# !gcc -o simulation simulation.cpp
# !./simulation simulation_settings.dat disk_initial_conditions.dat data_log.dat
# Out:
# Host nucleus:
# m = 10.000000
# x = 0.000000 y = 0.000000 z = 0.000000
# vx = 0.000000 vy = 0.000000 vz = 0.000000
# Intruder nucleus:
# m = 10.000000
# x = 0.000000 y = 0.000000 z = 10.000000
# vx = 0.000000 vy = 0.000000 vz = -10.000000
# Integration parameters:
# nout = 2 dt = 0.010000 mstep = 500 soft = 0.000000
# Number of points in disk: 256

# %% [markdown]
# ### Visualizing the simulation

# %%
# !python animate.py data_log.dat animation.mp4

# Visualize animation.mp4
from IPython.display import HTML
HTML('<iframe src="animation.mp4" width="800" height="600" frameborder="0" allowfullscreen></iframe>')
# Out:
# ^C
# Traceback (most recent call last):
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 231, in saving
#     yield self
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 1081, in save
#     anim._draw_next_frame(d, blit=False)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 1117, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 1142, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/backend_bases.py", line 2054, in draw_idle
#     self.draw(*args, **kwargs)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py", line 408, in draw
#     self.figure.draw(self.renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/artist.py", line 74, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/figure.py", line 3074, in draw
#     mimage._draw_list_compositing_images(
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axes3d.py", line 459, in draw
#     axis.draw(renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/mpl_toolkits/mplot3d/axis3d.py", line 397, in draw
#     self.label.draw(renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/artist.py", line 51, in draw_wrapper
#     return draw(artist, renderer)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/text.py", line 735, in draw
#     textrenderer.draw_text(gc, x, y, clean_line,
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py", line 210, in draw_text
#     font.set_text(s, 0, flags=get_hinting_flag())
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gk/Desktop/PHYS 141/ucsd-phys141-cartwheel-a/animate.py", line 58, in <module>
#     animation.save('animation.mp4', writer='ffmpeg')
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 1085, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 233, in saving
#     self.finish()
#   File "/Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/matplotlib/animation.py", line 347, in finish
#     raise subprocess.CalledProcessError(
# subprocess.CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '640x480', '-pix_fmt', 'rgba', '-r', '20.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', 'animation.mp4']' returned non-zero exit status 255.
# /Users/gk/opt/miniconda3/envs/py3k/lib/python3.9/site-packages/IPython/core/display.py:431: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="animation.mp4" width="800" height="600" frameborder="0" allowfullscreen></iframe>
